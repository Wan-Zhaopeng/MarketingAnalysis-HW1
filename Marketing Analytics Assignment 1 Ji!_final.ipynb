# %%
import pandas as pd
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.stats.api as sms
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil
from scipy.stats import norm
import statistics
import math

# %%
# dataset

# %%
df = pd.read_csv('AB_test_data.csv')

# %%
df.head()
# Out:
#    purchase_TF Variant        date        id
# 0        False       A  2019-11-08  0x25b44a
# 1        False       B  2020-08-27  0x46271e
# 2        False       A  2020-06-11  0x80b8f1
# 3        False       B  2020-08-22  0x8d736d
# 4        False       A  2020-08-05  0x96c9c8

# %%
pd.crosstab(df['purchase_TF'], df['Variant'])
# Out:
# Variant           A     B
# purchase_TF
# False        106298  4117
# True          18702   883

# %%
# Question 1

# %%
variant_A = df[df['Variant'] == 'A']
variant_B = df[df['Variant'] == 'B']

# %%
mean_a = sum(variant_A['purchase_TF'])/len(variant_A['purchase_TF'])
mean_b = sum(variant_B['purchase_TF'])/len(variant_B['purchase_TF'])
print(mean_a,mean_b)
# Out:
# 0.149616 0.1766

# %%
z_score = (mean_b - mean_a)/pow((mean_a*(1-mean_a))/len(variant_B),0.5) #one-sample z test
print(f'z score: {z_score:.2f}')
if z_score >= 1.64:
    print('Reject null hypothesis.')
else:
    print('Fail to Reject null hypothesis.')
# Out:
# z score: 5.35
# Reject null hypothesis.

# %%
# Question 2

# %%
# using a significance level of 0.05, and setting power to 0.80, we have tα/2 = 1.96 and tβ = 0.84 from standard normal tables.
tα_2 = 1.96
tβ = 0.84
pool_variance = mean_a*(1-mean_a)+mean_b*(1-mean_b)
n_1 = ceil((pool_variance/(mean_a-mean_b)**2)*((tβ+tα_2)**2))
n_1
# Out:
# 2936

# %%
# sample and test

# %%
for i in range(10,20):
    sample_B = variant_B.sample(n=n_1)
    conversion_b = sum(sample_B['purchase_TF'])/len(sample_B['purchase_TF'])
    z_score = (conversion_b - mean_a)/pow((mean_a*(1-mean_a))/len(sample_B),0.5)
    if z_score >= 1.64:
        print(f'z_score: {z_score:.2f}','Reject null hypothesis.')
    else:
        print(f'z_score: {z_score:.2f}','Fail to Reject null hypothesis.')
# Out:
# z_score: 3.71 Reject null hypothesis.
# z_score: 3.35 Reject null hypothesis.
# z_score: 3.71 Reject null hypothesis.
# z_score: 3.87 Reject null hypothesis.
# z_score: 3.97 Reject null hypothesis.
# z_score: 4.28 Reject null hypothesis.
# z_score: 3.76 Reject null hypothesis.
# z_score: 3.19 Reject null hypothesis.
# z_score: 4.75 Reject null hypothesis.
# z_score: 3.71 Reject null hypothesis.

# %%
# question 3

# %%
p_0 = mean_a
p_1 = mean_b

# %%
# set the boundaries: Set desired Type I error = 5% and Type II error = 20%

# %%
A = 2.99
B = -1.6

# %%
x_1 =math.log(mean_b/mean_a)
x_0 = math.log((1-mean_b)/(1-mean_a))
print(x_1,x_0)
# Out:
# 0.16581527647676866 -0.032245902839488846

# %%
stopping_times_list = []
for i in range(20,30):
    values = []
    stopping_times = 1
    x_cum = 0
    treatment_sample = variant_B.sample(n=n_1)
    for sample in treatment_sample['purchase_TF']:
        values.append(sample)
        if sample == 1:
            x_cum = x_cum + x_1
        else:
            x_cum = x_cum + x_0
        if x_cum>= A:
            stopping_times_list.append(stopping_times)
            print('Reject Null Hypothesis at iteration',f': {stopping_times:.2f}')
            break
        elif x_cum <= B:
            stopping_times_list.append(stopping_times)
            print('Reject Alternative Hypothesis at iteration',f': {stopping_times:.2f}')
            break
        elif stopping_times == n_1:
            stopping_times_list.append(stopping_times)
            print('Reach sample size, cannot stop early',f': {stopping_times:.2f}')
        stopping_times = stopping_times + 1

def Get_Average(list):
    sum = 0
    for item in list:
        sum += item
    return sum/len(list)
Get_Average(stopping_times_list)
# Out:
# Reject Alternative Hypothesis at iteration : 437.00
# Reject Null Hypothesis at iteration : 483.00
# Reject Alternative Hypothesis at iteration : 327.00
# Reject Null Hypothesis at iteration : 541.00
# Reject Null Hypothesis at iteration : 1123.00
# Reject Null Hypothesis at iteration : 507.00
# Reject Null Hypothesis at iteration : 746.00
# Reject Null Hypothesis at iteration : 552.00
# Reject Null Hypothesis at iteration : 1188.00
# Reject Null Hypothesis at iteration : 2860.00
# Reject Null Hypothesis at iteration : 507.00
# Reject Null Hypothesis at iteration : 887.00
# Reject Null Hypothesis at iteration : 649.00
# Reject Null Hypothesis at iteration : 477.00
# Reject Null Hypothesis at iteration : 489.00
# Reject Null Hypothesis at iteration : 739.00
# Reject Null Hypothesis at iteration : 888.00
# Reject Alternative Hypothesis at iteration : 259.00
# Reject Null Hypothesis at iteration : 2529.00
# Reject Null Hypothesis at iteration : 767.00
# Reject Alternative Hypothesis at iteration : 118.00
# Reject Alternative Hypothesis at iteration : 234.00
# Reject Alternative Hypothesis at iteration : 425.00
# Reject Null Hypothesis at iteration : 703.00
# Reject Null Hypothesis at iteration : 263.00
# Reject Null Hypothesis at iteration : 770.00
# Reject Null Hypothesis at iteration : 618.00
# Reject Null Hypothesis at iteration : 839.00
# Reject Null Hypothesis at iteration : 939.00
# Reject Null Hypothesis at iteration : 713.00
# Reject Null Hypothesis at iteration : 306.00
# Reject Alternative Hypothesis at iteration : 118.00
# Reject Null Hypothesis at iteration : 305.00
# Reject Null Hypothesis at iteration : 902.00
# Reject Null Hypothesis at iteration : 120.00
# Reject Null Hypothesis at iteration : 486.00
# Reject Null Hypothesis at iteration : 306.00
# Reject Null Hypothesis at iteration : 556.00
# Reject Null Hypothesis at iteration : 865.00
# Reject Null Hypothesis at iteration : 971.00
# Reject Null Hypothesis at iteration : 561.00
# Reject Null Hypothesis at iteration : 863.00
# Reject Null Hypothesis at iteration : 269.00
# Reject Null Hypothesis at iteration : 1687.00
# Reject Null Hypothesis at iteration : 1555.00
# Reject Null Hypothesis at iteration : 962.00
# Reject Null Hypothesis at iteration : 976.00
# Reject Null Hypothesis at iteration : 851.00
# Reject Null Hypothesis at iteration : 1734.00
# Reject Null Hypothesis at iteration : 888.00
# Reject Null Hypothesis at iteration : 613.00
# Reject Alternative Hypothesis at iteration : 406.00
# Reject Alternative Hypothesis at iteration : 142.00
# Reject Null Hypothesis at iteration : 312.00
# Reject Null Hypothesis at iteration : 1325.00
# Reject Null Hypothesis at iteration : 2062.00
# Reject Null Hypothesis at iteration : 561.00
# Reject Null Hypothesis at iteration : 552.00
# Reject Null Hypothesis at iteration : 503.00
# Reject Null Hypothesis at iteration : 821.00
# Reject Null Hypothesis at iteration : 598.00
# Reject Null Hypothesis at iteration : 417.00
# Reject Null Hypothesis at iteration : 1148.00
# Reject Null Hypothesis at iteration : 509.00
# Reject Null Hypothesis at iteration : 771.00
# Reject Null Hypothesis at iteration : 1914.00
# Reject Null Hypothesis at iteration : 312.00
# Reject Null Hypothesis at iteration : 753.00
# Reject Null Hypothesis at iteration : 961.00
# Reject Null Hypothesis at iteration : 1559.00
# Reject Null Hypothesis at iteration : 216.00
# Reject Null Hypothesis at iteration : 434.00
# Reject Null Hypothesis at iteration : 770.00
# Reject Null Hypothesis at iteration : 1182.00
# Reject Null Hypothesis at iteration : 238.00
# Reject Null Hypothesis at iteration : 202.00
# Reject Null Hypothesis at iteration : 1526.00
# Reject Null Hypothesis at iteration : 520.00
# Reject Null Hypothesis at iteration : 779.00
# Reject Null Hypothesis at iteration : 804.00
# Reject Alternative Hypothesis at iteration : 167.00
# Reject Null Hypothesis at iteration : 711.00
# Reject Null Hypothesis at iteration : 551.00
# Reject Null Hypothesis at iteration : 506.00
# Reject Null Hypothesis at iteration : 779.00
# Reject Null Hypothesis at iteration : 933.00
# Reject Null Hypothesis at iteration : 551.00
# Reject Alternative Hypothesis at iteration : 284.00
# Reject Null Hypothesis at iteration : 1608.00
# Reject Null Hypothesis at iteration : 1006.00
# Reject Null Hypothesis at iteration : 870.00
# Reject Null Hypothesis at iteration : 2229.00
# Reject Null Hypothesis at iteration : 459.00
# Reject Null Hypothesis at iteration : 567.00
# Reject Null Hypothesis at iteration : 1420.00
# Reject Null Hypothesis at iteration : 595.00
# Reject Null Hypothesis at iteration : 1184.00
# Reject Null Hypothesis at iteration : 658.00
# Reject Null Hypothesis at iteration : 882.00
# Reject Null Hypothesis at iteration : 444.00
# Reject Null Hypothesis at iteration : 992.00
# Reject Null Hypothesis at iteration : 435.00
# Reject Null Hypothesis at iteration : 212.00
# Reject Null Hypothesis at iteration : 1599.00
# Reject Null Hypothesis at iteration : 1306.00
# Reject Null Hypothesis at iteration : 1097.00
# Reject Null Hypothesis at iteration : 300.00
# Reject Null Hypothesis at iteration : 401.00
# Reject Null Hypothesis at iteration : 244.00
# Reject Null Hypothesis at iteration : 1243.00
# Reject Null Hypothesis at iteration : 1875.00
# Reject Null Hypothesis at iteration : 856.00
# Reject Null Hypothesis at iteration : 705.00
# Reject Null Hypothesis at iteration : 517.00
# Reject Null Hypothesis at iteration : 1349.00
# Reject Null Hypothesis at iteration : 723.00
# Reject Null Hypothesis at iteration : 1627.00
# Reject Null Hypothesis at iteration : 340.00
# Reject Null Hypothesis at iteration : 813.00
# Reject Alternative Hypothesis at iteration : 670.00
# Reject Null Hypothesis at iteration : 1255.00
# Reject Null Hypothesis at iteration : 693.00
# Reject Null Hypothesis at iteration : 912.00
# Reject Null Hypothesis at iteration : 2675.00
# Reject Null Hypothesis at iteration : 550.00
# Reject Null Hypothesis at iteration : 675.00
# Reject Null Hypothesis at iteration : 574.00
# Reject Alternative Hypothesis at iteration : 584.00
# Reject Null Hypothesis at iteration : 804.00
# Reject Null Hypothesis at iteration : 1478.00
# Reject Alternative Hypothesis at iteration : 62.00
# Reject Null Hypothesis at iteration : 711.00
# Reject Null Hypothesis at iteration : 545.00
# Reject Null Hypothesis at iteration : 364.00
# Reject Alternative Hypothesis at iteration : 173.00
# Reject Alternative Hypothesis at iteration : 167.00
# Reject Null Hypothesis at iteration : 292.00
# Reject Null Hypothesis at iteration : 257.00
# Reject Null Hypothesis at iteration : 229.00
# Reject Null Hypothesis at iteration : 711.00
# Reject Null Hypothesis at iteration : 1213.00
# Reject Null Hypothesis at iteration : 568.00
# Reject Null Hypothesis at iteration : 1673.00
# Reject Alternative Hypothesis at iteration : 228.00
# Reject Alternative Hypothesis at iteration : 155.00
# Reject Alternative Hypothesis at iteration : 247.00
# Reject Null Hypothesis at iteration : 1466.00
# Reject Alternative Hypothesis at iteration : 836.00
# Reject Null Hypothesis at iteration : 1391.00
# Reject Null Hypothesis at iteration : 892.00
# Reject Null Hypothesis at iteration : 1085.00
# Reject Null Hypothesis at iteration : 1466.00
# Reject Null Hypothesis at iteration : 777.00
# Reject Alternative Hypothesis at iteration : 327.00
# Reject Null Hypothesis at iteration : 336.00
# Reject Null Hypothesis at iteration : 374.00
# Reject Alternative Hypothesis at iteration : 867.00
# Reject Alternative Hypothesis at iteration : 179.00
# Reject Null Hypothesis at iteration : 660.00
# Reject Null Hypothesis at iteration : 896.00
# Reject Null Hypothesis at iteration : 515.00
# Reject Null Hypothesis at iteration : 707.00
# Reject Null Hypothesis at iteration : 519.00
# Reject Null Hypothesis at iteration : 632.00
# Reject Alternative Hypothesis at iteration : 302.00
# Reject Null Hypothesis at iteration : 545.00
# Reject Null Hypothesis at iteration : 546.00
# Reject Null Hypothesis at iteration : 416.00
# Reject Null Hypothesis at iteration : 1000.00
# Reject Null Hypothesis at iteration : 329.00
# Reject Null Hypothesis at iteration : 728.00
# Reject Null Hypothesis at iteration : 509.00
# Reject Null Hypothesis at iteration : 1718.00
# Reject Null Hypothesis at iteration : 561.00
# Reject Null Hypothesis at iteration : 837.00
# Reject Null Hypothesis at iteration : 771.00
# Reject Null Hypothesis at iteration : 671.00
# Reject Null Hypothesis at iteration : 459.00
# Reject Null Hypothesis at iteration : 291.00
# Reject Null Hypothesis at iteration : 288.00
# Reject Null Hypothesis at iteration : 561.00
# Reject Null Hypothesis at iteration : 1225.00
# Reject Null Hypothesis at iteration : 1025.00
# Reject Null Hypothesis at iteration : 690.00
# Reject Null Hypothesis at iteration : 306.00
# Reject Alternative Hypothesis at iteration : 492.00
# Reject Null Hypothesis at iteration : 1119.00
# Reject Null Hypothesis at iteration : 760.00
# Reject Null Hypothesis at iteration : 2374.00
# Reject Null Hypothesis at iteration : 446.00
# Reject Alternative Hypothesis at iteration : 161.00
# Reject Alternative Hypothesis at iteration : 1119.00
# Reject Null Hypothesis at iteration : 228.00
# Reject Null Hypothesis at iteration : 928.00
# Reject Null Hypothesis at iteration : 1458.00
# Reject Null Hypothesis at iteration : 2189.00
# Reject Null Hypothesis at iteration : 329.00
# Reject Null Hypothesis at iteration : 581.00
# Reject Null Hypothesis at iteration : 1534.00
# Reject Null Hypothesis at iteration : 1611.00
# Reject Null Hypothesis at iteration : 858.00
# Reject Null Hypothesis at iteration : 564.00
# Reject Alternative Hypothesis at iteration : 413.00
# Reject Null Hypothesis at iteration : 410.00
# Reject Null Hypothesis at iteration : 306.00
# Reject Null Hypothesis at iteration : 532.00
# Reject Alternative Hypothesis at iteration : 376.00
# Reject Null Hypothesis at iteration : 433.00
# Reject Null Hypothesis at iteration : 367.00
# Reject Null Hypothesis at iteration : 1845.00
# Reject Null Hypothesis at iteration : 1551.00
# Reject Null Hypothesis at iteration : 1074.00
# Reject Null Hypothesis at iteration : 366.00
# Reject Null Hypothesis at iteration : 773.00
# Reject Null Hypothesis at iteration : 741.00
# Reject Null Hypothesis at iteration : 212.00
# Reject Null Hypothesis at iteration : 595.00
# Reject Null Hypothesis at iteration : 759.00
# Reject Null Hypothesis at iteration : 653.00
# Reject Null Hypothesis at iteration : 968.00
# Reject Null Hypothesis at iteration : 201.00
# Reject Null Hypothesis at iteration : 991.00
# Reject Null Hypothesis at iteration : 601.00
# Reject Null Hypothesis at iteration : 2182.00
# Reject Null Hypothesis at iteration : 902.00
# Reject Null Hypothesis at iteration : 1088.00
# Reject Null Hypothesis at iteration : 746.00
# Reject Null Hypothesis at iteration : 1596.00
# Reject Alternative Hypothesis at iteration : 302.00
# Reject Null Hypothesis at iteration : 1498.00
# Reject Null Hypothesis at iteration : 637.00
# Reject Alternative Hypothesis at iteration : 425.00
# Reject Null Hypothesis at iteration : 1054.00
# Reject Null Hypothesis at iteration : 385.00
# Reject Null Hypothesis at iteration : 624.00
# Reject Null Hypothesis at iteration : 778.00
# Reject Null Hypothesis at iteration : 312.00
# Reject Null Hypothesis at iteration : 858.00
# Reject Null Hypothesis at iteration : 459.00
# Reject Null Hypothesis at iteration : 1341.00
# Reject Null Hypothesis at iteration : 822.00
# Reject Alternative Hypothesis at iteration : 253.00
# Reject Null Hypothesis at iteration : 870.00
# Reject Null Hypothesis at iteration : 292.00
# Reject Alternative Hypothesis at iteration : 179.00
# Reject Null Hypothesis at iteration : 394.00
# Reject Alternative Hypothesis at iteration : 191.00
# Reject Null Hypothesis at iteration : 722.00
# Reject Null Hypothesis at iteration : 827.00
# Reject Null Hypothesis at iteration : 573.00
# Reject Null Hypothesis at iteration : 1221.00
# Reject Null Hypothesis at iteration : 698.00
# Reject Null Hypothesis at iteration : 293.00
# Reject Null Hypothesis at iteration : 1809.00
# Reject Null Hypothesis at iteration : 1470.00
# Reject Alternative Hypothesis at iteration : 1119.00
# Reject Null Hypothesis at iteration : 562.00
# Reject Null Hypothesis at iteration : 772.00
# Reject Null Hypothesis at iteration : 1146.00
# Reject Null Hypothesis at iteration : 724.00
# Reject Null Hypothesis at iteration : 1019.00
# Reject Alternative Hypothesis at iteration : 1530.00
# Reject Null Hypothesis at iteration : 490.00
# Reject Null Hypothesis at iteration : 279.00
# Reject Null Hypothesis at iteration : 541.00
# Reject Null Hypothesis at iteration : 901.00
# Reject Null Hypothesis at iteration : 599.00
# Reject Null Hypothesis at iteration : 1045.00
# Reject Alternative Hypothesis at iteration : 425.00
# Reject Null Hypothesis at iteration : 317.00
# Reject Null Hypothesis at iteration : 933.00
# Reject Null Hypothesis at iteration : 1639.00
# Reject Null Hypothesis at iteration : 2798.00
# Reject Null Hypothesis at iteration : 1187.00
# Reject Null Hypothesis at iteration : 730.00
# Reject Null Hypothesis at iteration : 352.00
# Reject Alternative Hypothesis at iteration : 320.00
# Reject Null Hypothesis at iteration : 372.00
# Reject Null Hypothesis at iteration : 340.00
# Reject Alternative Hypothesis at iteration : 277.00
# Reject Null Hypothesis at iteration : 804.00
# Reject Null Hypothesis at iteration : 422.00
# Reject Null Hypothesis at iteration : 1123.00
# Reject Alternative Hypothesis at iteration : 222.00
# Reject Alternative Hypothesis at iteration : 210.00
# Reject Null Hypothesis at iteration : 631.00
# Reject Null Hypothesis at iteration : 906.00
# Reject Alternative Hypothesis at iteration : 241.00
# Reject Alternative Hypothesis at iteration : 296.00
# Reject Alternative Hypothesis at iteration : 253.00
# Reject Null Hypothesis at iteration : 550.00
# Reject Null Hypothesis at iteration : 715.00
# Reject Null Hypothesis at iteration : 386.00
# Reject Null Hypothesis at iteration : 478.00
# Reject Alternative Hypothesis at iteration : 388.00
# Reject Null Hypothesis at iteration : 667.00
# Reject Null Hypothesis at iteration : 514.00
# Reject Null Hypothesis at iteration : 902.00
# Reject Alternative Hypothesis at iteration : 849.00
# Reject Alternative Hypothesis at iteration : 382.00
# Reject Null Hypothesis at iteration : 628.00
# Reject Null Hypothesis at iteration : 961.00
# Reject Null Hypothesis at iteration : 1498.00
# Reject Null Hypothesis at iteration : 945.00
# Reject Null Hypothesis at iteration : 832.00
# Reject Null Hypothesis at iteration : 2136.00
# Reject Null Hypothesis at iteration : 1153.00
# Reject Alternative Hypothesis at iteration : 210.00
# Reject Null Hypothesis at iteration : 675.00
# Reject Alternative Hypothesis at iteration : 191.00
# Reject Null Hypothesis at iteration : 968.00
# Reject Null Hypothesis at iteration : 1482.00
# Reject Null Hypothesis at iteration : 673.00
# Reject Alternative Hypothesis at iteration : 732.00
# Reject Null Hypothesis at iteration : 681.00
# Reject Alternative Hypothesis at iteration : 191.00
# Reject Null Hypothesis at iteration : 322.00
# Reject Null Hypothesis at iteration : 756.00
# Reject Null Hypothesis at iteration : 810.00
# Reject Null Hypothesis at iteration : 383.00
# Reject Null Hypothesis at iteration : 728.00
# Reject Null Hypothesis at iteration : 1424.00
# Reject Null Hypothesis at iteration : 693.00
# Reject Null Hypothesis at iteration : 520.00
# Reject Null Hypothesis at iteration : 434.00
# Reject Null Hypothesis at iteration : 551.00
# Reject Null Hypothesis at iteration : 529.00
# Reject Null Hypothesis at iteration : 851.00
# Reject Null Hypothesis at iteration : 543.00
# Reject Null Hypothesis at iteration : 372.00
# Reject Null Hypothesis at iteration : 1584.00
# Reject Null Hypothesis at iteration : 1141.00
# Reject Null Hypothesis at iteration : 409.00
# Reject Null Hypothesis at iteration : 509.00
# Reject Null Hypothesis at iteration : 895.00
# Reject Null Hypothesis at iteration : 654.00
# Reject Null Hypothesis at iteration : 206.00
# Reject Null Hypothesis at iteration : 343.00
# Reject Alternative Hypothesis at iteration : 541.00
# Reject Alternative Hypothesis at iteration : 112.00
# Reject Null Hypothesis at iteration : 526.00
# Reject Null Hypothesis at iteration : 232.00
# Reject Null Hypothesis at iteration : 601.00
# Reject Null Hypothesis at iteration : 459.00
# Reject Null Hypothesis at iteration : 1084.00
# Reject Null Hypothesis at iteration : 388.00
# Reject Null Hypothesis at iteration : 532.00
# Reject Null Hypothesis at iteration : 256.00
# Reject Alternative Hypothesis at iteration : 216.00
# Reject Null Hypothesis at iteration : 1079.00
# Reject Null Hypothesis at iteration : 531.00
# Reject Null Hypothesis at iteration : 2775.00
# Reject Null Hypothesis at iteration : 691.00
# Reject Alternative Hypothesis at iteration : 148.00
# Reject Alternative Hypothesis at iteration : 124.00
# Reject Alternative Hypothesis at iteration : 314.00
# Reject Null Hypothesis at iteration : 912.00
# Reject Null Hypothesis at iteration : 545.00
# Reject Null Hypothesis at iteration : 417.00
# Reject Null Hypothesis at iteration : 1487.00
# Reject Alternative Hypothesis at iteration : 879.00
# Reject Alternative Hypothesis at iteration : 603.00
# Reject Null Hypothesis at iteration : 761.00
# Reject Alternative Hypothesis at iteration : 388.00
# Reject Alternative Hypothesis at iteration : 670.00
# Reject Null Hypothesis at iteration : 637.00
# Reject Null Hypothesis at iteration : 214.00
# Reject Null Hypothesis at iteration : 326.00
# Reject Null Hypothesis at iteration : 821.00
# Reject Null Hypothesis at iteration : 558.00
# Reject Null Hypothesis at iteration : 513.00
# Reject Null Hypothesis at iteration : 812.00
# Reject Alternative Hypothesis at iteration : 296.00
# Reject Null Hypothesis at iteration : 1725.00
# Reject Alternative Hypothesis at iteration : 388.00
# Reject Null Hypothesis at iteration : 1673.00
# Reject Null Hypothesis at iteration : 251.00
# Reject Alternative Hypothesis at iteration : 1328.00
# Reject Alternative Hypothesis at iteration : 339.00
# Reject Null Hypothesis at iteration : 843.00
# Reject Null Hypothesis at iteration : 1753.00
# Reject Null Hypothesis at iteration : 715.00
# Reject Null Hypothesis at iteration : 760.00
# Reject Null Hypothesis at iteration : 847.00
# Reject Null Hypothesis at iteration : 932.00
# Reject Alternative Hypothesis at iteration : 480.00
# Reject Alternative Hypothesis at iteration : 93.00
# Reject Null Hypothesis at iteration : 208.00
# Reject Null Hypothesis at iteration : 810.00
# Reject Null Hypothesis at iteration : 1274.00
# Reject Null Hypothesis at iteration : 880.00
# Reject Alternative Hypothesis at iteration : 480.00
# Reject Null Hypothesis at iteration : 955.00
# Reject Null Hypothesis at iteration : 1563.00
# Reject Null Hypothesis at iteration : 318.00
# Reject Null Hypothesis at iteration : 1240.00
# Reject Null Hypothesis at iteration : 416.00
# Reject Null Hypothesis at iteration : 966.00
# Reject Null Hypothesis at iteration : 218.00
# Reject Null Hypothesis at iteration : 1175.00
# Reject Null Hypothesis at iteration : 1171.00
# Reject Null Hypothesis at iteration : 1147.00
# Reject Null Hypothesis at iteration : 1252.00
# Reject Alternative Hypothesis at iteration : 720.00
# Reject Null Hypothesis at iteration : 976.00
# Reject Null Hypothesis at iteration : 414.00
# Reject Null Hypothesis at iteration : 693.00
# Reject Null Hypothesis at iteration : 804.00
# Reject Null Hypothesis at iteration : 675.00
# Reject Null Hypothesis at iteration : 423.00
# Reject Null Hypothesis at iteration : 212.00
# Reject Alternative Hypothesis at iteration : 443.00
# Reject Null Hypothesis at iteration : 154.00
# Reject Null Hypothesis at iteration : 546.00
# Reject Alternative Hypothesis at iteration : 370.00
# Reject Alternative Hypothesis at iteration : 167.00
# Reject Null Hypothesis at iteration : 366.00
# Reject Alternative Hypothesis at iteration : 308.00
# Reject Null Hypothesis at iteration : 670.00
# Reject Null Hypothesis at iteration : 1455.00
# Reject Null Hypothesis at iteration : 852.00
# Reject Null Hypothesis at iteration : 650.00
# Reject Alternative Hypothesis at iteration : 787.00
# Reject Null Hypothesis at iteration : 483.00
# Reject Null Hypothesis at iteration : 814.00
# Reject Null Hypothesis at iteration : 245.00
# Reject Null Hypothesis at iteration : 871.00
# Reject Null Hypothesis at iteration : 1429.00
# Reject Null Hypothesis at iteration : 377.00
# Reject Null Hypothesis at iteration : 797.00
# Reject Null Hypothesis at iteration : 1244.00
# Reject Null Hypothesis at iteration : 464.00
# Reject Alternative Hypothesis at iteration : 701.00
# Reject Null Hypothesis at iteration : 1459.00
# Reject Null Hypothesis at iteration : 814.00
# Reject Alternative Hypothesis at iteration : 394.00
# Reject Null Hypothesis at iteration : 557.00
# Reject Null Hypothesis at iteration : 619.00
# Reject Null Hypothesis at iteration : 315.00
# Reject Null Hypothesis at iteration : 649.00
# Reject Null Hypothesis at iteration : 1325.00
# Reject Null Hypothesis at iteration : 530.00
# Reject Null Hypothesis at iteration : 1074.00
# Reject Null Hypothesis at iteration : 517.00
# Reject Alternative Hypothesis at iteration : 664.00
# Reject Alternative Hypothesis at iteration : 1426.00
# Reject Null Hypothesis at iteration : 588.00
# Reject Alternative Hypothesis at iteration : 1186.00
# Reject Null Hypothesis at iteration : 1842.00
# Reject Alternative Hypothesis at iteration : 161.00
# Reject Null Hypothesis at iteration : 1000.00
# Reject Alternative Hypothesis at iteration : 93.00
# Reject Null Hypothesis at iteration : 847.00
# Reject Null Hypothesis at iteration : 992.00
# Reject Null Hypothesis at iteration : 2658.00
# Reject Null Hypothesis at iteration : 1116.00
# Reject Null Hypothesis at iteration : 280.00
# Reject Alternative Hypothesis at iteration : 216.00
# Reject Null Hypothesis at iteration : 1238.00
# Reject Null Hypothesis at iteration : 1269.00
# Reject Null Hypothesis at iteration : 374.00
# Reject Null Hypothesis at iteration : 249.00
# Reject Null Hypothesis at iteration : 1455.00
# Reject Null Hypothesis at iteration : 727.00
# Reject Null Hypothesis at iteration : 710.00
# Reject Null Hypothesis at iteration : 599.00
# Reject Alternative Hypothesis at iteration : 161.00
# Reject Null Hypothesis at iteration : 1190.00
# Reject Null Hypothesis at iteration : 1983.00
# Reject Null Hypothesis at iteration : 900.00
# Reject Null Hypothesis at iteration : 769.00
# Reject Null Hypothesis at iteration : 1068.00
# Reject Null Hypothesis at iteration : 1630.00
# Reject Null Hypothesis at iteration : 656.00
# Reject Alternative Hypothesis at iteration : 333.00
# Reject Null Hypothesis at iteration : 1736.00
# Reject Null Hypothesis at iteration : 665.00
# Reject Null Hypothesis at iteration : 918.00
# Reject Null Hypothesis at iteration : 787.00
# Reject Null Hypothesis at iteration : 783.00
# Reject Null Hypothesis at iteration : 1252.00
# Reject Alternative Hypothesis at iteration : 357.00
# Reject Null Hypothesis at iteration : 328.00
# Reject Null Hypothesis at iteration : 341.00
# Reject Null Hypothesis at iteration : 1200.00
# Reject Null Hypothesis at iteration : 1667.00
# Reject Null Hypothesis at iteration : 1405.00
# Reject Null Hypothesis at iteration : 624.00
# Reject Null Hypothesis at iteration : 1633.00
# Reject Alternative Hypothesis at iteration : 394.00
# Reject Null Hypothesis at iteration : 1117.00
# Reject Null Hypothesis at iteration : 431.00
# Reject Null Hypothesis at iteration : 843.00
# Reject Alternative Hypothesis at iteration : 277.00
# Reject Null Hypothesis at iteration : 1620.00
# Reject Null Hypothesis at iteration : 871.00
# Reject Null Hypothesis at iteration : 629.00
# Reject Null Hypothesis at iteration : 1012.00
# Reject Null Hypothesis at iteration : 847.00
# Reject Null Hypothesis at iteration : 791.00
# Reject Alternative Hypothesis at iteration : 185.00
# Reject Null Hypothesis at iteration : 869.00
# Reject Alternative Hypothesis at iteration : 198.00
# Reject Null Hypothesis at iteration : 1066.00
# Reject Null Hypothesis at iteration : 1643.00
# Reject Null Hypothesis at iteration : 713.00
# Reject Null Hypothesis at iteration : 339.00
# Reject Null Hypothesis at iteration : 317.00
# Reject Null Hypothesis at iteration : 237.00
# Reject Null Hypothesis at iteration : 1215.00
# Reject Null Hypothesis at iteration : 742.00
# Reject Null Hypothesis at iteration : 660.00
# Reject Alternative Hypothesis at iteration : 247.00
# Reject Null Hypothesis at iteration : 421.00
# Reject Null Hypothesis at iteration : 359.00
# Reject Null Hypothesis at iteration : 1000.00
# Reject Null Hypothesis at iteration : 1706.00
# Reject Null Hypothesis at iteration : 1206.00
# Reject Null Hypothesis at iteration : 225.00
# Reject Null Hypothesis at iteration : 1913.00
# Reject Alternative Hypothesis at iteration : 885.00
# Reject Null Hypothesis at iteration : 1447.00
# Reject Alternative Hypothesis at iteration : 971.00
# Reject Alternative Hypothesis at iteration : 198.00
# Reject Null Hypothesis at iteration : 420.00
# Reject Null Hypothesis at iteration : 675.00
# Reject Alternative Hypothesis at iteration : 93.00
# Reject Null Hypothesis at iteration : 483.00
# Reject Null Hypothesis at iteration : 407.00
# Reject Null Hypothesis at iteration : 1260.00
# Reject Null Hypothesis at iteration : 692.00
# Reject Null Hypothesis at iteration : 1399.00
# Reject Null Hypothesis at iteration : 598.00
# Reject Null Hypothesis at iteration : 679.00
# Reject Null Hypothesis at iteration : 735.00
# Reject Null Hypothesis at iteration : 997.00
# Reject Null Hypothesis at iteration : 902.00
# Reject Null Hypothesis at iteration : 1380.00
# Reject Alternative Hypothesis at iteration : 836.00
# Reject Alternative Hypothesis at iteration : 382.00
# Reject Null Hypothesis at iteration : 1245.00
# Reject Alternative Hypothesis at iteration : 449.00
# Reject Null Hypothesis at iteration : 652.00
# Reject Null Hypothesis at iteration : 563.00
# Reject Null Hypothesis at iteration : 384.00
# Reject Null Hypothesis at iteration : 2327.00
# Reject Alternative Hypothesis at iteration : 621.00
# Reject Alternative Hypothesis at iteration : 646.00
# Reject Null Hypothesis at iteration : 680.00
# Reject Null Hypothesis at iteration : 1174.00
# Reject Null Hypothesis at iteration : 650.00
# Reject Null Hypothesis at iteration : 778.00
# Reject Null Hypothesis at iteration : 1871.00
# Reject Null Hypothesis at iteration : 545.00
# Reject Null Hypothesis at iteration : 726.00
# Reject Null Hypothesis at iteration : 718.00
# Reject Null Hypothesis at iteration : 975.00
# Reject Null Hypothesis at iteration : 1670.00
# Reject Null Hypothesis at iteration : 1496.00
# Reject Null Hypothesis at iteration : 1201.00
# Reject Null Hypothesis at iteration : 1473.00
# Reject Null Hypothesis at iteration : 386.00
# Reject Null Hypothesis at iteration : 526.00
# Reject Alternative Hypothesis at iteration : 124.00
# Reject Alternative Hypothesis at iteration : 290.00
# Reject Null Hypothesis at iteration : 182.00
# Reject Alternative Hypothesis at iteration : 615.00
# Reject Null Hypothesis at iteration : 771.00
# Reject Null Hypothesis at iteration : 171.00
# Reject Alternative Hypothesis at iteration : 474.00
# Reject Null Hypothesis at iteration : 1310.00
# Reject Null Hypothesis at iteration : 1025.00
# Reject Alternative Hypothesis at iteration : 216.00
# Reject Null Hypothesis at iteration : 1280.00
# Reject Null Hypothesis at iteration : 555.00
# Reject Alternative Hypothesis at iteration : 578.00
# Reject Null Hypothesis at iteration : 187.00
# Reject Null Hypothesis at iteration : 229.00
# Reject Null Hypothesis at iteration : 1061.00
# Reject Null Hypothesis at iteration : 335.00
# Reject Null Hypothesis at iteration : 205.00
# Reject Alternative Hypothesis at iteration : 1156.00
# Reject Null Hypothesis at iteration : 406.00
# Reject Alternative Hypothesis at iteration : 1254.00
# Reject Null Hypothesis at iteration : 1018.00
# Reject Null Hypothesis at iteration : 1584.00
# Reject Null Hypothesis at iteration : 457.00
# Reject Alternative Hypothesis at iteration : 658.00
# Reject Null Hypothesis at iteration : 351.00
# Reject Null Hypothesis at iteration : 616.00
# Reject Null Hypothesis at iteration : 539.00
# Reject Null Hypothesis at iteration : 933.00
# Reject Null Hypothesis at iteration : 426.00
# Reject Null Hypothesis at iteration : 176.00
# Reject Null Hypothesis at iteration : 871.00
# Reject Null Hypothesis at iteration : 256.00
# Reject Null Hypothesis at iteration : 638.00
# Reject Null Hypothesis at iteration : 462.00
# Reject Null Hypothesis at iteration : 1338.00
# Reject Null Hypothesis at iteration : 634.00
# Reject Null Hypothesis at iteration : 445.00
# Reject Null Hypothesis at iteration : 1288.00
# Reject Null Hypothesis at iteration : 256.00
# Reject Null Hypothesis at iteration : 937.00
# Reject Null Hypothesis at iteration : 465.00
# Reject Alternative Hypothesis at iteration : 302.00
# Reject Null Hypothesis at iteration : 673.00
# Reject Null Hypothesis at iteration : 1245.00
# Reject Null Hypothesis at iteration : 1660.00
# Reject Null Hypothesis at iteration : 697.00
# Reject Null Hypothesis at iteration : 585.00
# Reject Null Hypothesis at iteration : 1009.00
# Reject Alternative Hypothesis at iteration : 130.00
# Reject Null Hypothesis at iteration : 353.00
# Reject Null Hypothesis at iteration : 581.00
# Reject Null Hypothesis at iteration : 689.00
# Reject Null Hypothesis at iteration : 797.00
# Reject Null Hypothesis at iteration : 249.00
# Reject Alternative Hypothesis at iteration : 572.00
# Reject Null Hypothesis at iteration : 527.00
# Reject Null Hypothesis at iteration : 683.00
# Reject Null Hypothesis at iteration : 1484.00
# Reject Alternative Hypothesis at iteration : 437.00
# Reject Null Hypothesis at iteration : 532.00
# Reject Null Hypothesis at iteration : 403.00
# Reject Null Hypothesis at iteration : 864.00
# Reject Null Hypothesis at iteration : 1270.00
# Reject Null Hypothesis at iteration : 1295.00
# Reject Null Hypothesis at iteration : 300.00
# Reject Null Hypothesis at iteration : 729.00
# Reject Null Hypothesis at iteration : 1541.00
# Reject Null Hypothesis at iteration : 360.00
# Reject Null Hypothesis at iteration : 446.00
# Reject Null Hypothesis at iteration : 466.00
# Reject Null Hypothesis at iteration : 1520.00
# Reject Null Hypothesis at iteration : 342.00
# Reject Null Hypothesis at iteration : 1318.00
# Reject Null Hypothesis at iteration : 988.00
# Reject Null Hypothesis at iteration : 251.00
# Reject Alternative Hypothesis at iteration : 105.00
# Reject Null Hypothesis at iteration : 679.00
# Reject Null Hypothesis at iteration : 279.00
# Reject Null Hypothesis at iteration : 900.00
# Reject Null Hypothesis at iteration : 951.00
# Reject Null Hypothesis at iteration : 644.00
# Reject Null Hypothesis at iteration : 445.00
# Reject Alternative Hypothesis at iteration : 204.00
# Reject Null Hypothesis at iteration : 493.00
# Reject Null Hypothesis at iteration : 840.00
# Reject Null Hypothesis at iteration : 907.00
# Reject Null Hypothesis at iteration : 595.00
# Reject Null Hypothesis at iteration : 881.00
# Reject Null Hypothesis at iteration : 1115.00
# Reject Null Hypothesis at iteration : 715.00
# Reject Alternative Hypothesis at iteration : 615.00
# Reject Null Hypothesis at iteration : 487.00
# Reject Alternative Hypothesis at iteration : 370.00
# Reject Alternative Hypothesis at iteration : 492.00
# Reject Null Hypothesis at iteration : 717.00
# Reject Null Hypothesis at iteration : 785.00
# Reject Alternative Hypothesis at iteration : 81.00
# Reject Null Hypothesis at iteration : 680.00
# Reject Null Hypothesis at iteration : 674.00
# Reject Null Hypothesis at iteration : 2063.00
# Reject Null Hypothesis at iteration : 446.00
# Reject Null Hypothesis at iteration : 982.00
# Reject Null Hypothesis at iteration : 632.00
# Reject Null Hypothesis at iteration : 628.00
# Reject Null Hypothesis at iteration : 256.00
# Reject Null Hypothesis at iteration : 619.00
# Reject Null Hypothesis at iteration : 975.00
# Reject Null Hypothesis at iteration : 1263.00
# Reject Null Hypothesis at iteration : 416.00
# Reject Null Hypothesis at iteration : 162.00
# Reject Null Hypothesis at iteration : 617.00
# Reject Null Hypothesis at iteration : 1875.00
# Reject Null Hypothesis at iteration : 556.00
# Reject Null Hypothesis at iteration : 1659.00
# Reject Null Hypothesis at iteration : 310.00
# Reject Null Hypothesis at iteration : 901.00
# Reject Alternative Hypothesis at iteration : 486.00
# Reject Null Hypothesis at iteration : 997.00
# Reject Null Hypothesis at iteration : 128.00
# Reject Alternative Hypothesis at iteration : 253.00
# Reject Null Hypothesis at iteration : 873.00
# Reject Alternative Hypothesis at iteration : 314.00
# Reject Null Hypothesis at iteration : 1343.00
# Reject Null Hypothesis at iteration : 428.00
# Reject Null Hypothesis at iteration : 1957.00
# Reject Null Hypothesis at iteration : 512.00
# Reject Null Hypothesis at iteration : 1275.00
# Reject Null Hypothesis at iteration : 1257.00
# Reject Null Hypothesis at iteration : 398.00
# Reject Null Hypothesis at iteration : 429.00
# Reject Null Hypothesis at iteration : 840.00
# Reject Null Hypothesis at iteration : 354.00
# Reject Alternative Hypothesis at iteration : 191.00
# Reject Null Hypothesis at iteration : 404.00
# Reject Null Hypothesis at iteration : 120.00
# Reject Null Hypothesis at iteration : 757.00
# Reject Null Hypothesis at iteration : 815.00
# Reject Null Hypothesis at iteration : 484.00
# Reject Null Hypothesis at iteration : 367.00
# Reject Null Hypothesis at iteration : 675.00
# Reject Null Hypothesis at iteration : 640.00
# Reject Null Hypothesis at iteration : 471.00
# Reject Null Hypothesis at iteration : 647.00
# Reject Alternative Hypothesis at iteration : 271.00
# Reject Null Hypothesis at iteration : 770.00
# Reject Null Hypothesis at iteration : 1864.00
# Reject Alternative Hypothesis at iteration : 124.00
# Reject Null Hypothesis at iteration : 739.00
# Reject Null Hypothesis at iteration : 992.00
# Reject Null Hypothesis at iteration : 1006.00
# Reject Null Hypothesis at iteration : 708.00
# Reject Null Hypothesis at iteration : 254.00
# Reject Alternative Hypothesis at iteration : 136.00
# Reject Null Hypothesis at iteration : 1232.00
# Reject Null Hypothesis at iteration : 661.00
# Reject Null Hypothesis at iteration : 1233.00
# Reject Null Hypothesis at iteration : 527.00
# Reject Null Hypothesis at iteration : 684.00
# Reject Null Hypothesis at iteration : 538.00
# Reject Null Hypothesis at iteration : 560.00
# Reject Null Hypothesis at iteration : 906.00
# Reject Null Hypothesis at iteration : 680.00
# Reject Null Hypothesis at iteration : 379.00
# Reject Null Hypothesis at iteration : 503.00
# Reject Null Hypothesis at iteration : 742.00
# Reject Null Hypothesis at iteration : 656.00
# Reject Null Hypothesis at iteration : 311.00
# Reject Alternative Hypothesis at iteration : 247.00
# Reject Null Hypothesis at iteration : 305.00
# Reject Null Hypothesis at iteration : 564.00
# Reject Null Hypothesis at iteration : 1025.00
# Reject Null Hypothesis at iteration : 957.00
# Reject Null Hypothesis at iteration : 174.00
# Reject Null Hypothesis at iteration : 948.00
# Reject Alternative Hypothesis at iteration : 351.00
# Reject Null Hypothesis at iteration : 1154.00
# Reject Null Hypothesis at iteration : 760.00
# Reject Null Hypothesis at iteration : 808.00
# Reject Null Hypothesis at iteration : 530.00
# Reject Null Hypothesis at iteration : 452.00
# Reject Null Hypothesis at iteration : 440.00
# Reject Null Hypothesis at iteration : 709.00
# Reject Null Hypothesis at iteration : 2713.00
# Reject Null Hypothesis at iteration : 1072.00
# Reject Null Hypothesis at iteration : 245.00
# Reject Null Hypothesis at iteration : 644.00
# Reject Alternative Hypothesis at iteration : 130.00
# Reject Null Hypothesis at iteration : 680.00
# Reject Null Hypothesis at iteration : 826.00
# Reject Null Hypothesis at iteration : 2179.00
# Reject Null Hypothesis at iteration : 1103.00
# Reject Null Hypothesis at iteration : 1105.00
# Reject Null Hypothesis at iteration : 1073.00
# Reject Null Hypothesis at iteration : 240.00
# Reject Alternative Hypothesis at iteration : 99.00
# Reject Null Hypothesis at iteration : 2001.00
# Reject Null Hypothesis at iteration : 439.00
# Reject Alternative Hypothesis at iteration : 867.00
# Reject Alternative Hypothesis at iteration : 62.00
# Reject Null Hypothesis at iteration : 341.00
# Reject Alternative Hypothesis at iteration : 142.00
# Reject Null Hypothesis at iteration : 600.00
# Reject Null Hypothesis at iteration : 2456.00
# Reject Null Hypothesis at iteration : 1676.00
# Reject Null Hypothesis at iteration : 456.00
# Reject Null Hypothesis at iteration : 1286.00
# Reject Null Hypothesis at iteration : 470.00
# Reject Alternative Hypothesis at iteration : 388.00
# Reject Alternative Hypothesis at iteration : 284.00
# Reject Alternative Hypothesis at iteration : 277.00
# Reject Alternative Hypothesis at iteration : 388.00
# Reject Null Hypothesis at iteration : 765.00
# Reject Null Hypothesis at iteration : 364.00
# Reject Null Hypothesis at iteration : 1116.00
# Reject Null Hypothesis at iteration : 1160.00
# Reject Null Hypothesis at iteration : 864.00
# Reject Null Hypothesis at iteration : 574.00
# Reject Null Hypothesis at iteration : 367.00
# Reject Null Hypothesis at iteration : 386.00
# Reject Null Hypothesis at iteration : 600.00
# Reject Alternative Hypothesis at iteration : 265.00
# Reject Null Hypothesis at iteration : 514.00
# Reject Null Hypothesis at iteration : 251.00
# Reject Null Hypothesis at iteration : 1307.00
# Reject Null Hypothesis at iteration : 1662.00
# Reject Alternative Hypothesis at iteration : 413.00
# Reject Null Hypothesis at iteration : 293.00
# Reject Null Hypothesis at iteration : 2510.00
# Reject Null Hypothesis at iteration : 1475.00
# Reject Null Hypothesis at iteration : 761.00
# Reject Null Hypothesis at iteration : 245.00
# Reject Null Hypothesis at iteration : 494.00
# Reject Null Hypothesis at iteration : 477.00
# Reject Null Hypothesis at iteration : 1187.00
# Reject Null Hypothesis at iteration : 740.00
# Reject Null Hypothesis at iteration : 624.00
# Reject Null Hypothesis at iteration : 341.00
# Reject Null Hypothesis at iteration : 202.00
# Reject Null Hypothesis at iteration : 693.00
# Reject Null Hypothesis at iteration : 1170.00
# Reject Null Hypothesis at iteration : 1410.00
# Reject Alternative Hypothesis at iteration : 683.00
# Reject Null Hypothesis at iteration : 1153.00
# Reject Null Hypothesis at iteration : 1562.00
# Reject Null Hypothesis at iteration : 704.00
# Reject Null Hypothesis at iteration : 1319.00
# Reject Null Hypothesis at iteration : 818.00
# Reject Null Hypothesis at iteration : 1883.00
# Reject Alternative Hypothesis at iteration : 683.00
# Reject Null Hypothesis at iteration : 581.00
# Reject Null Hypothesis at iteration : 508.00
# Reject Alternative Hypothesis at iteration : 971.00
# Reject Null Hypothesis at iteration : 456.00
# Reject Null Hypothesis at iteration : 877.00
# Reject Null Hypothesis at iteration : 1141.00
# Reject Null Hypothesis at iteration : 1675.00
# Reject Null Hypothesis at iteration : 1522.00
# Reject Null Hypothesis at iteration : 342.00
# Reject Null Hypothesis at iteration : 143.00
# Reject Null Hypothesis at iteration : 1115.00
# Reject Null Hypothesis at iteration : 931.00
# Reject Null Hypothesis at iteration : 1809.00
# Reject Null Hypothesis at iteration : 770.00
# Reject Null Hypothesis at iteration : 917.00
# Reject Null Hypothesis at iteration : 500.00
# Reject Alternative Hypothesis at iteration : 646.00
# Reject Null Hypothesis at iteration : 767.00
# Reject Null Hypothesis at iteration : 383.00
# Reject Null Hypothesis at iteration : 2092.00
# Reject Null Hypothesis at iteration : 2253.00
# Reject Null Hypothesis at iteration : 691.00
# Reject Null Hypothesis at iteration : 1343.00
# Reject Null Hypothesis at iteration : 1098.00
# Reject Null Hypothesis at iteration : 437.00
# Reject Null Hypothesis at iteration : 999.00
# Reject Null Hypothesis at iteration : 2122.00
# Reject Null Hypothesis at iteration : 385.00
# Reject Alternative Hypothesis at iteration : 234.00
# Reject Null Hypothesis at iteration : 742.00
# Reject Null Hypothesis at iteration : 1220.00
# Reject Alternative Hypothesis at iteration : 234.00
# Reject Null Hypothesis at iteration : 723.00
# Reject Null Hypothesis at iteration : 262.00
# Reject Null Hypothesis at iteration : 784.00
# Reject Null Hypothesis at iteration : 796.00
# Reject Null Hypothesis at iteration : 501.00
# Reject Null Hypothesis at iteration : 422.00
# Reject Null Hypothesis at iteration : 828.00
# Reject Null Hypothesis at iteration : 753.00
# Reject Null Hypothesis at iteration : 1287.00
# Reject Null Hypothesis at iteration : 545.00
# Reject Null Hypothesis at iteration : 335.00
# Reject Null Hypothesis at iteration : 294.00
# Reject Alternative Hypothesis at iteration : 155.00
# Reject Alternative Hypothesis at iteration : 499.00
# Reject Alternative Hypothesis at iteration : 247.00
# Reject Null Hypothesis at iteration : 1125.00
# Reject Null Hypothesis at iteration : 803.00
# Reject Null Hypothesis at iteration : 372.00
# Reject Null Hypothesis at iteration : 906.00
# Reject Null Hypothesis at iteration : 638.00
# Reject Alternative Hypothesis at iteration : 142.00
# Reject Null Hypothesis at iteration : 197.00
# Reject Alternative Hypothesis at iteration : 1684.00
# Reject Null Hypothesis at iteration : 1178.00
# Reject Null Hypothesis at iteration : 1102.00
# Reject Null Hypothesis at iteration : 423.00
# Reject Null Hypothesis at iteration : 568.00
# Reject Null Hypothesis at iteration : 570.00
# Reject Null Hypothesis at iteration : 415.00
# Reject Alternative Hypothesis at iteration : 1481.00
# Reject Null Hypothesis at iteration : 434.00
# Reject Null Hypothesis at iteration : 1565.00
# Reject Null Hypothesis at iteration : 1455.00
# Reject Null Hypothesis at iteration : 1065.00
# Reject Null Hypothesis at iteration : 306.00
# Reject Null Hypothesis at iteration : 754.00
# Reject Null Hypothesis at iteration : 1270.00
# Reject Alternative Hypothesis at iteration : 339.00
# Reject Null Hypothesis at iteration : 280.00
# Reject Null Hypothesis at iteration : 408.00
# Reject Null Hypothesis at iteration : 1967.00
# Reject Null Hypothesis at iteration : 570.00
# Reject Null Hypothesis at iteration : 975.00
# Reject Alternative Hypothesis at iteration : 947.00
# Reject Null Hypothesis at iteration : 465.00
# Reject Null Hypothesis at iteration : 1448.00
# Reject Null Hypothesis at iteration : 561.00
# Reject Null Hypothesis at iteration : 187.00
# Reject Null Hypothesis at iteration : 643.00
# Reject Null Hypothesis at iteration : 2105.00
# Reject Null Hypothesis at iteration : 434.00
# Reject Alternative Hypothesis at iteration : 425.00
# Reject Null Hypothesis at iteration : 1326.00
# Reject Null Hypothesis at iteration : 1133.00
# Reject Null Hypothesis at iteration : 696.00
# Reject Null Hypothesis at iteration : 1733.00
# Reject Null Hypothesis at iteration : 508.00
# Reject Null Hypothesis at iteration : 810.00
# Reject Alternative Hypothesis at iteration : 419.00
# Reject Null Hypothesis at iteration : 852.00
# Reject Alternative Hypothesis at iteration : 388.00
# Reject Null Hypothesis at iteration : 764.00
# Reject Null Hypothesis at iteration : 699.00
# Reject Null Hypothesis at iteration : 2385.00
# Reject Null Hypothesis at iteration : 245.00
# Reject Null Hypothesis at iteration : 693.00
# Reject Null Hypothesis at iteration : 1114.00
# Reject Null Hypothesis at iteration : 667.00
# Reject Null Hypothesis at iteration : 679.00
# Reject Null Hypothesis at iteration : 354.00
# Reject Alternative Hypothesis at iteration : 75.00
# Reject Alternative Hypothesis at iteration : 1561.00
# Reject Null Hypothesis at iteration : 1115.00
# Reject Null Hypothesis at iteration : 269.00
# Reject Alternative Hypothesis at iteration : 124.00
# Reject Null Hypothesis at iteration : 1448.00
# Reject Null Hypothesis at iteration : 268.00
# Reject Null Hypothesis at iteration : 659.00
# Reject Null Hypothesis at iteration : 1000.00
# Reject Null Hypothesis at iteration : 736.00
# Reject Null Hypothesis at iteration : 589.00
# Reject Null Hypothesis at iteration : 877.00
# Reject Null Hypothesis at iteration : 1068.00
# Reject Null Hypothesis at iteration : 414.00
# Reject Null Hypothesis at iteration : 558.00
# Reject Null Hypothesis at iteration : 1755.00
# Reject Null Hypothesis at iteration : 793.00
# Reject Alternative Hypothesis at iteration : 505.00
# Reject Null Hypothesis at iteration : 1085.00
# Reject Null Hypothesis at iteration : 1017.00
# Reject Null Hypothesis at iteration : 201.00
# Reject Null Hypothesis at iteration : 575.00
# Reject Null Hypothesis at iteration : 986.00
# Reject Null Hypothesis at iteration : 1479.00
# Reject Null Hypothesis at iteration : 697.00
# Reject Null Hypothesis at iteration : 2037.00
# Reject Null Hypothesis at iteration : 945.00
# Reject Null Hypothesis at iteration : 949.00
# Reject Null Hypothesis at iteration : 417.00
# Reject Null Hypothesis at iteration : 759.00
# Reject Alternative Hypothesis at iteration : 621.00
# Reject Null Hypothesis at iteration : 674.00
# Reject Null Hypothesis at iteration : 1372.00
# Reject Null Hypothesis at iteration : 177.00
# Reject Null Hypothesis at iteration : 340.00
# Reject Alternative Hypothesis at iteration : 486.00
# Reject Alternative Hypothesis at iteration : 382.00
# Reject Null Hypothesis at iteration : 385.00
# Reject Null Hypothesis at iteration : 815.00
# Reject Null Hypothesis at iteration : 298.00
# Reject Alternative Hypothesis at iteration : 142.00
# Reject Null Hypothesis at iteration : 185.00
# Reject Null Hypothesis at iteration : 367.00
# Reject Null Hypothesis at iteration : 588.00
# Reject Null Hypothesis at iteration : 595.00
# Reject Null Hypothesis at iteration : 616.00
# Reject Null Hypothesis at iteration : 771.00
# Reject Null Hypothesis at iteration : 281.00
# Reject Null Hypothesis at iteration : 412.00
# Reject Null Hypothesis at iteration : 1341.00
# Reject Null Hypothesis at iteration : 1066.00
# Reject Null Hypothesis at iteration : 617.00
# Reject Null Hypothesis at iteration : 644.00
# Reject Null Hypothesis at iteration : 967.00
# Reject Null Hypothesis at iteration : 975.00
# Reject Null Hypothesis at iteration : 318.00
# Reject Null Hypothesis at iteration : 1128.00
# Reject Alternative Hypothesis at iteration : 314.00
# Reject Null Hypothesis at iteration : 1171.00
# Reject Alternative Hypothesis at iteration : 726.00
# Reject Null Hypothesis at iteration : 404.00
# Reject Null Hypothesis at iteration : 466.00
# Reject Alternative Hypothesis at iteration : 191.00
# Reject Null Hypothesis at iteration : 982.00
# Reject Null Hypothesis at iteration : 722.00
# Reject Null Hypothesis at iteration : 309.00
# Reject Null Hypothesis at iteration : 593.00
# Reject Null Hypothesis at iteration : 255.00
# Reject Alternative Hypothesis at iteration : 228.00
# Reject Null Hypothesis at iteration : 1111.00
# Reject Null Hypothesis at iteration : 1215.00
# Reject Null Hypothesis at iteration : 1885.00
# Reject Alternative Hypothesis at iteration : 228.00
# Reject Null Hypothesis at iteration : 787.00
# Reject Alternative Hypothesis at iteration : 376.00
# Reject Alternative Hypothesis at iteration : 511.00
# Reject Null Hypothesis at iteration : 477.00
# Reject Null Hypothesis at iteration : 331.00
# Reject Alternative Hypothesis at iteration : 259.00
# Reject Null Hypothesis at iteration : 1737.00
# Reject Alternative Hypothesis at iteration : 253.00
# Reject Null Hypothesis at iteration : 606.00
# Reject Null Hypothesis at iteration : 463.00
# Reject Null Hypothesis at iteration : 281.00
# Reject Null Hypothesis at iteration : 549.00
# Reject Null Hypothesis at iteration : 999.00
# Reject Null Hypothesis at iteration : 594.00
# Reject Null Hypothesis at iteration : 472.00
# Reject Null Hypothesis at iteration : 847.00
# Reject Null Hypothesis at iteration : 552.00
# Reject Null Hypothesis at iteration : 460.00
# Reject Null Hypothesis at iteration : 513.00
# Reject Null Hypothesis at iteration : 371.00
# Reject Null Hypothesis at iteration : 1195.00
# Reject Null Hypothesis at iteration : 708.00
# Reject Null Hypothesis at iteration : 383.00
# Reject Null Hypothesis at iteration : 920.00
# Reject Null Hypothesis at iteration : 724.00
# Reject Null Hypothesis at iteration : 1137.00
# Reject Null Hypothesis at iteration : 450.00
# Reject Null Hypothesis at iteration : 435.00
# Reject Null Hypothesis at iteration : 818.00
# Reject Null Hypothesis at iteration : 875.00
# Reject Null Hypothesis at iteration : 896.00
# Reject Null Hypothesis at iteration : 514.00
# Reject Alternative Hypothesis at iteration : 486.00
# Reject Null Hypothesis at iteration : 392.00
# Reject Alternative Hypothesis at iteration : 413.00
# Reject Null Hypothesis at iteration : 784.00
# Reject Null Hypothesis at iteration : 951.00
# Reject Null Hypothesis at iteration : 236.00
# Reject Null Hypothesis at iteration : 1805.00
# Reject Null Hypothesis at iteration : 573.00
# Reject Null Hypothesis at iteration : 643.00
# Reject Null Hypothesis at iteration : 1417.00
# Reject Null Hypothesis at iteration : 2763.00
# Reject Alternative Hypothesis at iteration : 1014.00
# Reject Alternative Hypothesis at iteration : 370.00
# ...
# Reject Null Hypothesis at iteration : 470.00
# Reject Alternative Hypothesis at iteration : 713.00
# Reject Null Hypothesis at iteration : 488.00
# Reject Null Hypothesis at iteration : 410.00
# Reject Null Hypothesis at iteration : 975.00
# Reject Null Hypothesis at iteration : 263.00
# Reject Null Hypothesis at iteration : 643.00
# Reject Null Hypothesis at iteration : 1078.00
# Reject Alternative Hypothesis at iteration : 75.00
# Reject Alternative Hypothesis at iteration : 191.00
# Reject Null Hypothesis at iteration : 477.00
# Reject Null Hypothesis at iteration : 1004.00
# Reject Null Hypothesis at iteration : 963.00
# Reject Null Hypothesis at iteration : 619.00
# Reject Alternative Hypothesis at iteration : 363.00
# Reject Alternative Hypothesis at iteration : 339.00
# Reject Null Hypothesis at iteration : 427.00
# Reject Null Hypothesis at iteration : 1049.00
# Reject Null Hypothesis at iteration : 158.00
# Reject Alternative Hypothesis at iteration : 572.00
# Reject Null Hypothesis at iteration : 347.00
# Reject Null Hypothesis at iteration : 551.00
# Reject Null Hypothesis at iteration : 850.00
# Reject Null Hypothesis at iteration : 1483.00
# Reject Alternative Hypothesis at iteration : 228.00
# Reject Null Hypothesis at iteration : 1430.00
# Reject Null Hypothesis at iteration : 864.00
# Reject Null Hypothesis at iteration : 317.00
# Reject Null Hypothesis at iteration : 134.00
# Reject Null Hypothesis at iteration : 869.00
# Reject Null Hypothesis at iteration : 414.00
# Reject Null Hypothesis at iteration : 2194.00
# Reject Null Hypothesis at iteration : 730.00
# Reject Null Hypothesis at iteration : 1375.00
# Reject Null Hypothesis at iteration : 594.00
# Reject Null Hypothesis at iteration : 1541.00
# Reject Null Hypothesis at iteration : 881.00
# Reject Null Hypothesis at iteration : 996.00
# Reject Null Hypothesis at iteration : 306.00
# Reject Null Hypothesis at iteration : 936.00
# Reject Null Hypothesis at iteration : 1225.00
# Reject Null Hypothesis at iteration : 187.00
# Reject Null Hypothesis at iteration : 144.00
# Reject Null Hypothesis at iteration : 466.00
# Reject Null Hypothesis at iteration : 330.00
# Reject Null Hypothesis at iteration : 1575.00
# Reject Null Hypothesis at iteration : 943.00
# Reject Null Hypothesis at iteration : 503.00
# Reject Null Hypothesis at iteration : 992.00
# Reject Null Hypothesis at iteration : 440.00
# Reject Alternative Hypothesis at iteration : 308.00
# Reject Null Hypothesis at iteration : 924.00
# Reject Null Hypothesis at iteration : 1445.00
# Reject Alternative Hypothesis at iteration : 904.00
# Reject Null Hypothesis at iteration : 364.00
# Reject Null Hypothesis at iteration : 1307.00
# Reject Alternative Hypothesis at iteration : 560.00
# Reject Null Hypothesis at iteration : 1866.00
# Reject Alternative Hypothesis at iteration : 130.00
# Reject Null Hypothesis at iteration : 612.00
# Reject Alternative Hypothesis at iteration : 155.00
# Reject Null Hypothesis at iteration : 619.00
# Reject Null Hypothesis at iteration : 778.00
# Reject Null Hypothesis at iteration : 611.00
# Reject Null Hypothesis at iteration : 144.00
# Reject Null Hypothesis at iteration : 810.00
# Reject Null Hypothesis at iteration : 870.00
# Reject Null Hypothesis at iteration : 986.00
# Reject Null Hypothesis at iteration : 478.00
# Reject Alternative Hypothesis at iteration : 984.00
# Reject Null Hypothesis at iteration : 1251.00
# Reject Null Hypothesis at iteration : 648.00
# Reject Alternative Hypothesis at iteration : 560.00
# Reject Null Hypothesis at iteration : 1028.00
# Reject Null Hypothesis at iteration : 923.00
# Reject Null Hypothesis at iteration : 966.00
# Reject Null Hypothesis at iteration : 250.00
# Reject Null Hypothesis at iteration : 895.00
# Reject Alternative Hypothesis at iteration : 105.00
# Reject Null Hypothesis at iteration : 535.00
# Reject Null Hypothesis at iteration : 1471.00
# Reject Null Hypothesis at iteration : 1338.00
# Reject Null Hypothesis at iteration : 606.00
# Reject Null Hypothesis at iteration : 668.00
# Reject Null Hypothesis at iteration : 455.00
# Reject Null Hypothesis at iteration : 1299.00
# Reject Null Hypothesis at iteration : 1691.00
# Reject Alternative Hypothesis at iteration : 419.00
# Reject Alternative Hypothesis at iteration : 327.00
# Reject Null Hypothesis at iteration : 939.00
# Reject Null Hypothesis at iteration : 231.00
# Reject Null Hypothesis at iteration : 678.00
# Reject Null Hypothesis at iteration : 298.00
# Reject Null Hypothesis at iteration : 1692.00
# Reject Null Hypothesis at iteration : 1133.00
# Reject Null Hypothesis at iteration : 754.00
# Reach sample size, cannot stop early : 2936.0
# Reject Alternative Hypothesis at iteration : 517.00
# Reject Null Hypothesis at iteration : 2060.00
# Reject Null Hypothesis at iteration : 546.00
# Reject Null Hypothesis at iteration : 748.00
# Reject Null Hypothesis at iteration : 532.00
# Reject Null Hypothesis at iteration : 518.00
# Reject Null Hypothesis at iteration : 531.00
# Reject Null Hypothesis at iteration : 483.00
# Reject Null Hypothesis at iteration : 324.00
# Reject Null Hypothesis at iteration : 925.00
# Reject Null Hypothesis at iteration : 2152.00
# Reject Alternative Hypothesis at iteration : 173.00
# Reject Null Hypothesis at iteration : 1347.00
# Reject Null Hypothesis at iteration : 280.00
# Reject Null Hypothesis at iteration : 311.00
# Reject Null Hypothesis at iteration : 703.00
# Reject Null Hypothesis at iteration : 482.00
# Reject Null Hypothesis at iteration : 263.00
# Reject Null Hypothesis at iteration : 864.00
# Reject Null Hypothesis at iteration : 1440.00
# Reject Null Hypothesis at iteration : 340.00
# Reject Null Hypothesis at iteration : 355.00
# Reject Null Hypothesis at iteration : 2413.00
# Reject Null Hypothesis at iteration : 875.00
# Reject Null Hypothesis at iteration : 1012.00
# Reject Null Hypothesis at iteration : 1375.00
# Reject Alternative Hypothesis at iteration : 916.00
# Reject Null Hypothesis at iteration : 976.00
# Reject Null Hypothesis at iteration : 785.00
# Reject Null Hypothesis at iteration : 1034.00
# Reject Null Hypothesis at iteration : 245.00
# Reject Null Hypothesis at iteration : 779.00
# Reject Null Hypothesis at iteration : 441.00
# Reject Null Hypothesis at iteration : 551.00
# Reject Alternative Hypothesis at iteration : 1100.00
# Reject Null Hypothesis at iteration : 707.00
# Reject Null Hypothesis at iteration : 1030.00
# Reject Null Hypothesis at iteration : 865.00
# Reject Null Hypothesis at iteration : 973.00
# Reject Alternative Hypothesis at iteration : 284.00
# Reject Null Hypothesis at iteration : 799.00
# Reject Null Hypothesis at iteration : 555.00
# Reject Null Hypothesis at iteration : 1183.00
# Reject Alternative Hypothesis at iteration : 234.00
# Reject Alternative Hypothesis at iteration : 130.00
# Reject Null Hypothesis at iteration : 545.00
# Reject Null Hypothesis at iteration : 617.00
# Reject Null Hypothesis at iteration : 1325.00
# Reject Null Hypothesis at iteration : 1387.00
# Reject Null Hypothesis at iteration : 969.00
# Reject Null Hypothesis at iteration : 681.00
# Reject Null Hypothesis at iteration : 2000.00
# Reject Null Hypothesis at iteration : 380.00
# Reject Alternative Hypothesis at iteration : 443.00
# Reject Null Hypothesis at iteration : 483.00
# Reject Null Hypothesis at iteration : 2057.00
# Reject Null Hypothesis at iteration : 998.00
# Reject Alternative Hypothesis at iteration : 677.00
# Reject Null Hypothesis at iteration : 593.00
# Reject Null Hypothesis at iteration : 465.00
# Reject Null Hypothesis at iteration : 1053.00
# Reject Null Hypothesis at iteration : 637.00
# Reject Null Hypothesis at iteration : 515.00
# Reject Null Hypothesis at iteration : 761.00
# Reject Null Hypothesis at iteration : 724.00
# Reject Null Hypothesis at iteration : 678.00
# Reject Null Hypothesis at iteration : 475.00
# Reject Null Hypothesis at iteration : 373.00
# Reject Null Hypothesis at iteration : 1270.00
# Reject Null Hypothesis at iteration : 476.00
# Reject Null Hypothesis at iteration : 962.00
# Reject Alternative Hypothesis at iteration : 400.00
# Reject Null Hypothesis at iteration : 593.00
# Reject Null Hypothesis at iteration : 1030.00
# Reject Null Hypothesis at iteration : 444.00
# Reject Alternative Hypothesis at iteration : 388.00
# Reject Null Hypothesis at iteration : 1090.00
# Reject Null Hypothesis at iteration : 458.00
# Reject Null Hypothesis at iteration : 1482.00
# Reject Null Hypothesis at iteration : 312.00
# Reject Null Hypothesis at iteration : 623.00
# Reject Null Hypothesis at iteration : 1764.00
# Reject Null Hypothesis at iteration : 396.00
# Reject Alternative Hypothesis at iteration : 136.00
# Reject Alternative Hypothesis at iteration : 173.00
# Reject Null Hypothesis at iteration : 379.00
# Reject Null Hypothesis at iteration : 202.00
# Reject Null Hypothesis at iteration : 945.00
# Reject Null Hypothesis at iteration : 2017.00
# Reject Null Hypothesis at iteration : 686.00
# Reject Null Hypothesis at iteration : 275.00
# Reject Null Hypothesis at iteration : 360.00
# Reject Null Hypothesis at iteration : 541.00
# Reject Null Hypothesis at iteration : 675.00
# Reject Alternative Hypothesis at iteration : 394.00
# Reject Null Hypothesis at iteration : 323.00
# Reject Alternative Hypothesis at iteration : 707.00
# Reject Null Hypothesis at iteration : 328.00
# Reject Null Hypothesis at iteration : 236.00
# Reject Null Hypothesis at iteration : 812.00
# Reject Null Hypothesis at iteration : 1134.00
# Reject Null Hypothesis at iteration : 1457.00
# Reject Null Hypothesis at iteration : 973.00
# Reject Null Hypothesis at iteration : 1534.00
# Reject Null Hypothesis at iteration : 379.00
# Reject Null Hypothesis at iteration : 309.00
# Reject Alternative Hypothesis at iteration : 689.00
# Reject Null Hypothesis at iteration : 611.00
# Reject Alternative Hypothesis at iteration : 198.00
# Reject Null Hypothesis at iteration : 287.00
# Reject Null Hypothesis at iteration : 765.00
# Reject Alternative Hypothesis at iteration : 584.00
# Reject Null Hypothesis at iteration : 217.00
# Reject Null Hypothesis at iteration : 930.00
# Reject Null Hypothesis at iteration : 924.00
# Reject Null Hypothesis at iteration : 1036.00
# Reject Alternative Hypothesis at iteration : 1211.00
# Reject Null Hypothesis at iteration : 1025.00
# Reject Null Hypothesis at iteration : 1840.00
# Reject Null Hypothesis at iteration : 496.00
# Reject Null Hypothesis at iteration : 1105.00
# Reject Null Hypothesis at iteration : 503.00
# Reject Null Hypothesis at iteration : 385.00
# Reject Alternative Hypothesis at iteration : 167.00
# Reject Null Hypothesis at iteration : 455.00
# Reject Alternative Hypothesis at iteration : 216.00
# Reject Null Hypothesis at iteration : 318.00
# Reject Null Hypothesis at iteration : 1895.00
# Reject Null Hypothesis at iteration : 489.00
# Reject Null Hypothesis at iteration : 484.00
# Reject Null Hypothesis at iteration : 686.00
# Reject Null Hypothesis at iteration : 398.00
# Reject Alternative Hypothesis at iteration : 296.00
# Reject Alternative Hypothesis at iteration : 271.00
# Reject Null Hypothesis at iteration : 948.00
# Reject Alternative Hypothesis at iteration : 670.00
# Reject Null Hypothesis at iteration : 1138.00
# Reject Null Hypothesis at iteration : 902.00
# Reject Alternative Hypothesis at iteration : 775.00
# Reject Null Hypothesis at iteration : 361.00
# Reject Null Hypothesis at iteration : 865.00
# Reject Null Hypothesis at iteration : 939.00
# Reject Null Hypothesis at iteration : 226.00
# Reject Null Hypothesis at iteration : 1528.00
# Reject Null Hypothesis at iteration : 374.00
# Reject Alternative Hypothesis at iteration : 216.00
# Reject Null Hypothesis at iteration : 1280.00
# Reject Null Hypothesis at iteration : 1141.00
# Reject Null Hypothesis at iteration : 766.00
# Reject Alternative Hypothesis at iteration : 185.00
# Reject Null Hypothesis at iteration : 505.00
# Reject Null Hypothesis at iteration : 716.00
# Reject Null Hypothesis at iteration : 1725.00
# Reject Null Hypothesis at iteration : 1349.00
# Reject Null Hypothesis at iteration : 649.00
# Reject Null Hypothesis at iteration : 271.00
# Reject Null Hypothesis at iteration : 1289.00
# Reject Null Hypothesis at iteration : 628.00
# Reject Alternative Hypothesis at iteration : 363.00
# Reject Null Hypothesis at iteration : 1123.00
# Reject Null Hypothesis at iteration : 920.00
# Reject Alternative Hypothesis at iteration : 320.00
# Reject Alternative Hypothesis at iteration : 130.00
# Reject Null Hypothesis at iteration : 395.00
# Reject Null Hypothesis at iteration : 226.00
# Reject Alternative Hypothesis at iteration : 744.00
# Reject Null Hypothesis at iteration : 1442.00
# Reject Null Hypothesis at iteration : 116.00
# Reject Null Hypothesis at iteration : 543.00
# Reject Null Hypothesis at iteration : 2579.00
# Reject Alternative Hypothesis at iteration : 277.00
# Reject Alternative Hypothesis at iteration : 431.00
# Reject Null Hypothesis at iteration : 435.00
# Reject Null Hypothesis at iteration : 1489.00
# Reject Alternative Hypothesis at iteration : 431.00
# Reject Null Hypothesis at iteration : 969.00
# Reject Null Hypothesis at iteration : 727.00
# Reject Null Hypothesis at iteration : 1322.00
# Reject Null Hypothesis at iteration : 1451.00
# Reject Null Hypothesis at iteration : 1448.00
# Reject Alternative Hypothesis at iteration : 480.00
# Reject Null Hypothesis at iteration : 384.00
# Reject Null Hypothesis at iteration : 631.00
# Reject Null Hypothesis at iteration : 1373.00
# Reject Null Hypothesis at iteration : 987.00
# Reject Null Hypothesis at iteration : 1613.00
# Reject Null Hypothesis at iteration : 828.00
# Reject Null Hypothesis at iteration : 1306.00
# Reject Null Hypothesis at iteration : 1395.00
# Reject Null Hypothesis at iteration : 347.00
# Reject Null Hypothesis at iteration : 601.00
# Reject Null Hypothesis at iteration : 440.00
# Reject Null Hypothesis at iteration : 478.00
# Reject Null Hypothesis at iteration : 734.00
# Reject Null Hypothesis at iteration : 828.00
# Reject Null Hypothesis at iteration : 1132.00
# Reject Null Hypothesis at iteration : 2140.00
# Reject Null Hypothesis at iteration : 1189.00
# Reject Null Hypothesis at iteration : 950.00
# Reject Null Hypothesis at iteration : 2233.00
# Reject Null Hypothesis at iteration : 662.00
# Reject Alternative Hypothesis at iteration : 185.00
# Reject Null Hypothesis at iteration : 551.00
# Reject Null Hypothesis at iteration : 1950.00
# Reject Null Hypothesis at iteration : 883.00
# Reject Alternative Hypothesis at iteration : 499.00
# Reject Alternative Hypothesis at iteration : 572.00
# Reject Alternative Hypothesis at iteration : 142.00
# Reject Null Hypothesis at iteration : 2068.00
# Reject Alternative Hypothesis at iteration : 308.00
# Reject Null Hypothesis at iteration : 337.00
# Reject Alternative Hypothesis at iteration : 1260.00
# Reject Null Hypothesis at iteration : 163.00
# Reject Null Hypothesis at iteration : 226.00
# Reject Null Hypothesis at iteration : 342.00
# Reject Null Hypothesis at iteration : 469.00
# Reject Alternative Hypothesis at iteration : 763.00
# Reject Null Hypothesis at iteration : 975.00
# Reject Null Hypothesis at iteration : 656.00
# Reject Null Hypothesis at iteration : 672.00
# Reject Null Hypothesis at iteration : 1201.00
# Reject Null Hypothesis at iteration : 855.00
# Reject Alternative Hypothesis at iteration : 664.00
# Reject Null Hypothesis at iteration : 862.00
# Reject Null Hypothesis at iteration : 433.00
# Reject Null Hypothesis at iteration : 1055.00
# Reject Null Hypothesis at iteration : 2196.00
# Reject Null Hypothesis at iteration : 1613.00
# Reject Null Hypothesis at iteration : 1645.00
# Reject Null Hypothesis at iteration : 563.00
# Reject Null Hypothesis at iteration : 1619.00
# Reject Null Hypothesis at iteration : 180.00
# Reject Null Hypothesis at iteration : 288.00
# Reject Alternative Hypothesis at iteration : 241.00
# Reject Null Hypothesis at iteration : 1606.00
# Reject Null Hypothesis at iteration : 678.00
# Reject Null Hypothesis at iteration : 438.00
# Reject Null Hypothesis at iteration : 1036.00
# Reject Null Hypothesis at iteration : 330.00
# Reject Null Hypothesis at iteration : 962.00
# Reject Null Hypothesis at iteration : 827.00
# Reject Null Hypothesis at iteration : 280.00
# Reject Null Hypothesis at iteration : 2293.00
# Reject Null Hypothesis at iteration : 1115.00
# Reject Null Hypothesis at iteration : 255.00
# Reject Null Hypothesis at iteration : 447.00
# 773.9261306532663
